# %% [markdown]
# ### Prompt template and chat prompt template
#
# #### 1. PromptTemplate
#
# A PromptTemplate is a string with named placeholders. You fill them in at runtime.
#
# Use PromptTemplate when working with plain LLMs (text-in).

# %%
from langchain_core.prompts import PromptTemplate

template = PromptTemplate.from_template(
    "You are an AI assistant. Answer this question: {question}"
)

prompt = template.invoke({"question": "What is LangChain?"})

print(prompt)
# Out:
# text='You are an AI assistant. Answer this question: What is LangChain?'

# %% [markdown]
# ### 2. ChatPromptTemplate
#
# Chat models expect a list of messages. ChatPromptTemplate lets you template that list with variables.

# %%
from langchain_core.prompts import ChatPromptTemplate

#The system message sets the context; the human message is the user's input. Both accept variables.
template = ChatPromptTemplate.from_messages([
    ("system", "You are an expert in {topic}. Be concise."),
    ("human", "{question}"),
])

prompt = template.invoke({"topic": "Python", "question": "What is a  dictionary?"})

print(prompt)
# Out:
# messages=[SystemMessage(content='You are an expert in Python. Be concise.', additional_kwargs={}, response_metadata={}), HumanMessage(content='What is a  dictionary?', additional_kwargs={}, response_metadata={})]

# %% [markdown]
# *For chat models, use ChatPromptTemplate!*
